# %% [markdown]
# <a href="https://colab.research.google.com/github/fightmeat/Machine_Leaning/blob/main/15_Pandas_groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Groupby : 같은 값을 하나로 묶어 통계 또는 집계결과를 얻기 위한 기능

# %%
df = pd.DataFrame({
   'city':['부산','부산','부산','부산','서울','서울','서울'],
    'fruits':['apple','orange','banana','banana','apple','apple','banana'],
    'price':[100,200,250,300,150,200,400],
    'quantity':[1,2,3,4,5,6,7]
})
df
# Out:
#   city  fruits  price  quantity
# 0   부산   apple    100         1
# 1   부산  orange    200         2
# 2   부산  banana    250         3
# 3   부산  banana    300         4
# 4   서울   apple    150         5
# 5   서울   apple    200         6
# 6   서울  banana    400         7

# %% [markdown]
# #### get_group() : 그룹 안에 데이터를 확인

# %%
df.groupby('city').mean()
# Out:
# <ipython-input-3-1de92c00fe84>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('city').mean()
#       price  quantity
# city
# 부산    212.5       2.5
# 서울    250.0       6.0

# %%
df.groupby('city').get_group('부산')
# Out:
#   city  fruits  price  quantity
# 0   부산   apple    100         1
# 1   부산  orange    200         2
# 2   부산  banana    250         3
# 3   부산  banana    300         4

# %% [markdown]
# #### size() : 각 그룹의 사이즈 확인

# %%
df.groupby('city').size()
# Out:
# city
# 부산    4
# 서울    3
# dtype: int64

# %%
df.groupby('city').size()['부산']
# Out:
# 4

# %% [markdown]
# #### agg() : Aggregation의 약자

# %%
df.groupby('city').agg(np.mean)
# Out:
# <ipython-input-12-d3e542c46df5>:1: FutureWarning: The operation <function mean at 0x7bf2d98a03a0> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   df.groupby('city').agg(np.mean)
#       price  quantity
# city
# 부산    212.5       2.5
# 서울    250.0       6.0

# %%
# 가격 평균과 수량은 합계를 동시에 계산
def my_mean(s):
    return np.mean(s)

df.groupby('city').agg({'price':my_mean,'quantity':sum})
# Out:
#       price  quantity
# city
# 부산    212.5        10
# 서울    250.0        18

# %% [markdown]
# ### 대륙과 국가별 음주 소비량을 분석한 데이터셋
# - 각각의 피처들간의 상관관계 파악
# - 아프리카와 유럽간의 맥주 소비량 차이 검정

# %%
drinks = pd.read_csv('drinks.csv')
drinks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       193 non-null    object
#  1   beer_servings                 193 non-null    int64
#  2   spirit_servings               193 non-null    int64
#  3   wine_servings                 193 non-null    int64
#  4   total_litres_of_pure_alcohol  193 non-null    float64
#  5   continent                     170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %%
drinks.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %%
# 각 피처들간의 상관관계 파악 - pearson 상관계수

# %%
corr = drinks[['beer_servings','wine_servings']].corr(method='pearson')
print(corr)
# Out:
#                beer_servings  wine_servings
# beer_servings       1.000000       0.527172
# wine_servings       0.527172       1.000000

# %% [markdown]
# ### 여러 피처들간의 상관계수 분석

# %%
cols = ['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol']
corr = drinks[cols].corr(method='pearson')
print(corr)
# Out:
#                               beer_servings  spirit_servings  wine_servings  \
# beer_servings                      1.000000         0.458819       0.527172
# spirit_servings                    0.458819         1.000000       0.194797
# wine_servings                      0.527172         0.194797       1.000000
# total_litres_of_pure_alcohol       0.835839         0.654968       0.667598
#
#                               total_litres_of_pure_alcohol
# beer_servings                                     0.835839
# spirit_servings                                   0.654968
# wine_servings                                     0.667598
# total_litres_of_pure_alcohol                      1.000000

# %%
# heatmap으로 시각화

# %%
# 산점도 시각화(sns.pairplot)

# %%
# 대륙(continent)의 결측값을 대체값(OT)로 채우는 작업
## 결측여부 확인: isnull().sum()
## 결측값 대체 : fillna(value)
drinks['continent'] = drinks['continent'].fillna('OT')
drinks.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF
# 5                           4.9        OT
# 6                           8.3        SA
# 7                           3.8        EU
# 8                          10.4        OC
# 9                           9.7        EU

# %%
# 대륙별로 맥주 소비량의 최대, 최소, 평균을 추출
res = drinks.groupby('continent')['beer_servings'].agg(['max','min','mean'])
res
# Out:
#            max  min        mean
# continent
# AF         376    0   61.471698
# AS         247    0   37.045455
# EU         361    0  193.777778
# OC         306    0   89.687500
# OT         285    1  145.434783
# SA         333   93  175.083333

# %%
# idxmax() : Series 객체에서 값이 가장 큰 index를 반환하는 메서드
# 평균 맥주 소비량이 가장 큰 대륙은?
res = drinks.groupby('continent')['beer_servings'].mean().idxmax()
res
# Out:
# 'EU'

# %%
# t-test : 차이검정 # 정규분포를 해야한다.
# 아프리카와 유럽 간의 맥주 소비량 차이를 검정
from scipy import stats # import scipy.stats as stats
africa = drinks[drinks['continent'] == 'AF']
africa
europe = drinks[drinks['continent'] == 'EU']
europe
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# 60              Finland            263              133             97
# 61               France            127              151            370
# 64              Georgia             52              100            149
# 65              Germany            346              117            175
# 67               Greece            133              112            218
# 75              Hungary            234              215            185
# 76              Iceland            233               61             78
# 81              Ireland            313              118            165
# 83                Italy             85               42            237
# 93               Latvia            281              216             62
# 98            Lithuania            343              244             56
# 99           Luxembourg            236              133            271
# 105               Malta            149              100            120
# 111              Monaco              0                0              0
# 113          Montenegro             31              114            128
# 120         Netherlands            251               88            190
# 126              Norway            169               71            129
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 139             Moldova            109              226             18
# 140             Romania            297              122            167
# 147          San Marino              0                0              0
# 151              Serbia            283              131            127
# 155            Slovakia            196              293            116
# 156            Slovenia            270               51            276
# 160               Spain            284              157            112
# 165              Sweden            152               60            186
# 166         Switzerland            185              100            280
# 170           Macedonia            106               27             86
# 180             Ukraine            206              237             45
# 182      United Kingdom            219              126            195
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# 3                            12.4        EU
# 7                             3.8        EU
# 9                             9.7        EU
# 10                            1.3        EU
# 15                           14.4        EU
# 16                           10.5        EU
# 21                            4.6        EU
# 25                           10.3        EU
# 42                           10.2        EU
# 44                            8.2        EU
# 45                           11.8        EU
# 48                           10.4        EU
# 57                            9.5        EU
# 60                           10.0        EU
# 61                           11.8        EU
# 64                            5.4        EU
# 65                           11.3        EU
# 67                            8.3        EU
# 75                           11.3        EU
# 76                            6.6        EU
# 81                           11.4        EU
# 83                            6.5        EU
# 93                           10.5        EU
# 98                           12.9        EU
# 99                           11.4        EU
# 105                           6.6        EU
# 111                           0.0        EU
# 113                           4.9        EU
# 120                           9.4        EU
# 126                           6.7        EU
# 135                          10.9        EU
# 136                          11.0        EU
# 139                           6.3        EU
# 140                          10.4        EU
# 147                           0.0        EU
# 151                           9.6        EU
# 155                          11.4        EU
# 156                          10.6        EU
# 160                          10.0        EU
# 165                           7.2        EU
# 166                          10.2        EU
# 170                           3.9        EU
# 180                           8.9        EU
# 182                          10.4        EU

# %%
# 정규분포 - 정규성
# 임계값 또는 유효범위 0.05
# shapiro test - 정규성 검증, p-value > 0.05면 정규분포를 따른다.
# p-value > 0.05면 정규분포를 따른다.
sha_a, sha_pvalue = stats.shapiro(africa['beer_servings'])
print(sha_a, sha_pvalue)
# Out:
# 0.6982115507125854 3.84315423929138e-09

# %%
# 등분산 : 분산의 동질성 검사, levene test
e, p = stats.levene(africa['beer_servings'], europe['beer_servings'])
print(e,p)
if  p > 0.05:
    print('등분산이다.')
else:
    print('등분산이 아니다.')
# Out:
# 6.015144059118397 0.015989187968374834
# 등분산이 아니다.
